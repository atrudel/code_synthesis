# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../../game')))
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from coach import Coach
from NeuralNetworkWrapper import NNetWrapper
from GOLAI.arena import Arena
from game import Game
from utils import dotdict
import torch
import time

args = dotdict({
    
    #Program
    'numIters': 100000,
    'numEps': 3000,
    'vocabWidth': 2, 
    'vocabHeight': 2,
    'programSize': 10,
    'programWidth': 10,
    'programHeight': 10,
    'predictionLen': (10*10) // (2*2),
    'vocabLen': 2**(2*2), 
    
    # Simulations
    'tempThreshold': 15,
    'updateThreshold': 0.6,
    'maxlenOfQueue': 200000,
    'numMCTSSims': 16,
    'arenaCompare': 40,
    'cpuct': 1,
    'eps': 0.25,
    'alpha': 0.3, # 0.03 for Go 0.3 for Chess
    'dirichlet_noise': True,
    
    # Game 
    'gameSteps': 100,
    'gameHeight': 25, 
    'gameWidth': 25,
    
    # Model
    'lr': 0.001,
    'dropout': 0.3,
    'epochs': 20,
    'batch_size': 3000,
    'cuda': torch.cuda.is_available(),
    'num_channels': 512,
    'resnetBlocks': 10,
    'resnetInputDepth': 1,
    'resnetChannelDepth': 64,
    'checkpoint': './checkpoint_expand/',
    'load_model': False,
    
    # Save and Load
    'savePrograms': True,
    'time': str(int(time.time())),
    'output_dir': "./output_expand/",
    'load_folder_file': ('./checkpoint_expand/', 'checkpoint_4.pth.tar'),
    'numItersForTrainExamplesHistory': 20,
})

if __name__=="__main__":
    g = Game(args, Arena(args.gameWidth, args.gameHeight))
    nnet = NNetWrapper(args)
    
    if args.load_model:
        nnet.load_checkpoint(args.load_folder_file[0], args.load_folder_file[1])
        
    c = Coach(g, nnet, args)
    if args.load_model:
        print("Load trainExamples from file")
        c.loadTrainExamples()
    c.learn()
    
# Structure from: https://github.com/suragnair/alpha-zero-general/blob/master/main.py
# Out:
# Load trainExamples from file
# File with trainExamples found. Read it.
# ---------Iter 1---------
# Self Play |################################| (10/10 Eps Time: 0.804 | Total: 0:00:08 | ETA:                                     0:00:01
#
# Wins: -2.0
# Checkpoint Directory exists!
# Checkpoint Directory exists!
# EPOCH ::: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b3252f0a0d8f> in <module>()
#      71         print("Load trainExamples from file")
#      72         c.loadTrainExamples()
# ---> 73     c.learn()
#      74
#      75 # Structure from: https://github.com/suragnair/alpha-zero-general/blob/master/main.py
#
# ~/ewallner/jobs/golai/ai-players/golai_zero/coach.py in learn(self)
#     145
#     146             mcts = MCTS(self.game, self.nnet, self.args)  # why?
# --> 147             self.nnet.train(trainExamples)
#     148
#     149     def getCheckpointFile(self, iteration):
#
# ~/ewallner/jobs/golai/ai-players/golai_zero/NeuralNetworkWrapper.py in train(self, examples)
#      65
#      66                 # compute output
# ---> 67                 out_pi, out_v = self.nnet(programs)
#      68                 l_pi = self.loss_pi(target_pis, out_pi)
#      69                 l_v = self.loss_v(target_vs, out_v)
#
# ~/ewallner/ew_venv5/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/ewallner/jobs/golai/ai-players/golai_zero/model.py in forward(self, x)
#      90     def forward(self, x):
#      91         x = x.view(-1, 1, self.args.programWidth, self.args.programHeight)
# ---> 92         features = self.resnet(x)
#      93         policy_out = self.policyhead(features)
#      94         value_out = self.valuehead(features)
#
# ~/ewallner/ew_venv5/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/ewallner/jobs/golai/ai-players/golai_zero/model.py in forward(self, x)
#      44     def forward(self, x):
#      45         x = self.conv1(x)
# ---> 46         x = self.resnetblock(x)
#      47         return x
#      48
#
# ~/ewallner/ew_venv5/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/ewallner/ew_venv5/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/ewallner/ew_venv5/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/ewallner/jobs/golai/ai-players/golai_zero/model.py in forward(self, x)
#      22
#      23     def forward(self, x):
# ---> 24         out = self.conv1(x)
#      25         out = F.relu(self.b1(out))
#      26         out = self.conv2(out)
#
# ~/ewallner/ew_venv5/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/ewallner/ew_venv5/lib/python3.5/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# KeyboardInterrupt:
